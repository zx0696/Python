# %%
# 필요 모듈
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://news.daum.net'

# %%
res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
bs_obj = BeautifulSoup(res.content,'html.parser')

# %%
bs_obj
# Out:
# <!DOCTYPE html>
#
# <html class="os_unknown none unknown version_0" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="always" name="referrer">
# <meta content="Daum 뉴스" property="og:author"/>
# <meta content="다음뉴스" property="og:site_name"/>
# <meta content="홈" property="og:title"/>
# <meta content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" property="og:image"/>
# <meta content="다음뉴스" property="og:description"/>
# <meta content="https://news.daum.net/" property="og:url"/>
# <link href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico" rel="shortcut icon"/>
# <title>홈 | 다음뉴스</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="//t1.daumcdn.net/media/kraken/news/efee66e/style.css.merged.css" rel="stylesheet" type="text/css">
# <link href="//t1.daumcdn.net/media/kraken/news/efee66e/calendar.css.merged.css" rel="stylesheet" type="text/css"/>
# <!--[if lte IE 8]>
# ...

# %%
cate = [s.text for s in bs_obj.findAll(class_= 'txt_category')]

# %%
len(cate)
# Out:
# 20

# %%
bs_obj.find(class_='tit_g').text.replace('\n','').strip()
# Out:
# '눈 가렵고 끈적인다…전파력 더 센 코로나 새 변이 확산'

# %%
title = [s.text.replace('\n','').strip()for s in bs_obj.findAll(class_='tit_g')]

# %%
len(title)
# Out:
# 32

# %%
# 카테고리와 기사 제목의 추출 개수가 다름 
# 카테고리와 타이틀을 모두 담고 있는 태그를 찾아 진행

# %%
.item_issue
# Out:
#   Input In [19]
#     .item_issue
#     ^
# SyntaxError: invalid syntax

# %%
news = bs_obj.select('.item_issue')

# %%
len(news)
# Out:
# 20

# %%
news[0].find(class_='txt_category').text

# %%
news[0].find(class_='tit_g').text.replace('\n','').strip()
# Out:
# '눈 가렵고 끈적인다…전파력 더 센 코로나 새 변이 확산'

# %%
cate = [n.find(class_='txt_category').text for n in news]
title = [n.find(class_='tit_g').text.replace('\n','').strip() for n in news]

# %%
len(cate),len(title)
# Out:
# (20, 20)

# %%
pd.DataFrame({'section':cate, '제목':title})
# Out:
#    section                                                 제목
# 0       속보                     눈 가렵고 끈적인다…전파력 더 센 코로나 새 변이 확산
# 1       경제                 화면엔 35만원, 결제땐 42만원…‘눈속임 상술’ 뿌리 뽑는다
# 2       정치                        “與도 野도 싫다” 무당층 31%…대선 이후 최대
# 3       IT                [오늘과학] 통증 없이 약물 전달하는 손바닥 크기 웨어러블 패치
# 4       IT                           삼성-구글, 든든한 동맹에서 선의의 경쟁으로
# 5       국제            [영상] 이란 '국군의날' 퍼레이드 전략무기 대거 공개…드론 강국 과시
# 6       사회                폭우에 공사장서 동료 구하다 숨진 안준호씨 등 2명 의사자 인정
# 7       사회                    울릉도 500㎍/㎥… 이번엔 동쪽서 유입된 황사 “왜?”
# 8       국제             [영상] 스페이스X '역대최강 로켓' 공중폭발…머스크 "한수 배웠다"
# 9       경제                            거짓할인 미끼… 온라인 ‘다크패턴’ 주의보
# 10      정치           여당, 尹 우크라·대만 발언 엄호…"민주, 정치적 이익 위해 외교 자해"
# 11      국제                 지갑 여는 中, 노동절 여행 예약 급증…"코로나 이전 웃돌아"
# 12      사회                      최승호 취임 후 MBC 보도국 '3노조' 24명→0명
# 13      경제                   원·달러 환율, 종가 기준 연고점 경신…1328.2원 마감
# ...
