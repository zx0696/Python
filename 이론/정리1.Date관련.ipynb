# %%
### 날짜 자동생성 : date_range()

# %%
import pandas as pd
import numpy as np

# %%
index_date = ['2018-10-07','2018-10-08','2018-10-09','2018-10-10']
s4 = pd.Series([200,195,np.nan,205],index = index_date)
s4
# np.nan : 수치형 데이터
# Out:
# 2018-10-07    200.0
# 2018-10-08    195.0
# 2018-10-09      NaN
# 2018-10-10    205.0
# dtype: float64

# %%
type(s4.index[0]) # str
# Out:
# str

# %% [markdown]
# - 판다스 패키지의 date_range 함수 (날짜생성)
#     - pd.date_range(start=None, end=None, periods=None, freq='D')
#     - start : 시작날짜/ end= 끝날짜 / periods = 날짜 생성기간/ fref = 날짜 생성 주기
#     - start는 필수 옵션/end나 periods는 둘 중 하나가 있어야 함/ freq는 기본 Day로 설정
#     ![image.png](attachment:image.png)

# %%
pd.date_range(start='2018-10-01', end = '2018-10-20', freq='d')
# DatetimeIndex
#dtype = 'datetime64[ns] : 수치계산이 가능'
# freq ='d' 기본값
# Out:
# DatetimeIndex(['2018-10-01', '2018-10-02', '2018-10-03', '2018-10-04',
#                '2018-10-05', '2018-10-06', '2018-10-07', '2018-10-08',
#                '2018-10-09', '2018-10-10', '2018-10-11', '2018-10-12',
#                '2018-10-13', '2018-10-14', '2018-10-15', '2018-10-16',
#                '2018-10-17', '2018-10-18', '2018-10-19', '2018-10-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2018-10-01', end = '2018-10-20', freq='3d') 
# 3일씩 증가된 날짜 생성
# Out:
# DatetimeIndex(['2018-10-01', '2018-10-04', '2018-10-07', '2018-10-10',
#                '2018-10-13', '2018-10-16', '2018-10-19'],
#               dtype='datetime64[ns]', freq='3D')

# %%
pd.date_range(start='2018-10-01', end = '2018-10-20', freq='w')
# 2018-10-01일을 기준으로 1주일씩 증가하는 날짜 
# 1주 시작일인 일요일을 표시 
# 2018-10-01 - 월요일
# Out:
# DatetimeIndex(['2018-10-07', '2018-10-14'], dtype='datetime64[ns]', freq='W-SUN')

# %%
pd.date_range(start='2018-10-01', periods=4, freq='m')
# 2018 - 10 - 01일 이후  각 월에 마지막 날짜 4개 생성
# Out:
# DatetimeIndex(['2018-10-31', '2018-11-30', '2018-12-31', '2019-01-31'], dtype='datetime64[ns]', freq='M')

# %%
pd.date_range(start='2018-10-01', periods=4, freq='M')
# Out:
# DatetimeIndex(['2018-10-31', '2018-11-30', '2018-12-31', '2019-01-31'], dtype='datetime64[ns]', freq='M')

# %%
# 각 월에 시작 날짜 : MS는 대문자 소대문자 의미가 달라지기 때문 
pd.date_range(start='2018-10-01', periods=4, freq='MS')
# Out:
# DatetimeIndex(['2018-10-01', '2018-11-01', '2018-12-01', '2019-01-01'], dtype='datetime64[ns]', freq='MS')

# %%
# 2BM 업무일 기준 2개월 간격 월말주기 
pd.date_range(start='2018-10-01', periods=4, freq='2BM')
# Out:
# DatetimeIndex(['2018-10-31', '2018-12-31', '2019-02-28', '2019-04-30'], dtype='datetime64[ns]', freq='2BM')

# %%
# 1년을 4분기로 나눈 분기 시작일 기준  10/1일부터 분기 시작함. 
pd.date_range(start='2018-10-01', periods=4, freq='QS')
# Out:
# DatetimeIndex(['2018-10-01', '2019-01-01', '2019-04-01', '2019-07-01'], dtype='datetime64[ns]', freq='QS-JAN')

# %%
# AS : 연도 시작일 
pd.date_range(start='2018-10-01', periods=4, freq='AS')
# Out:
# DatetimeIndex(['2019-01-01', '2020-01-01', '2021-01-01', '2022-01-01'], dtype='datetime64[ns]', freq='AS-JAN')

# %% [markdown]
# ● date_range()시간생성

# %%
pd.date_range(start='2018-10-01 08:00', periods=10, freq='H')
# Out:
# DatetimeIndex(['2018-10-01 08:00:00', '2018-10-01 09:00:00',
#                '2018-10-01 10:00:00', '2018-10-01 11:00:00',
#                '2018-10-01 12:00:00', '2018-10-01 13:00:00',
#                '2018-10-01 14:00:00', '2018-10-01 15:00:00',
#                '2018-10-01 16:00:00', '2018-10-01 17:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
# 업무시간 기준 : 9 to 4 설정 
pd.date_range(start='2018-10-01 08:00', periods=10, freq='BH')
# Out:
# DatetimeIndex(['2018-10-01 09:00:00', '2018-10-01 10:00:00',
#                '2018-10-01 11:00:00', '2018-10-01 12:00:00',
#                '2018-10-01 13:00:00', '2018-10-01 14:00:00',
#                '2018-10-01 15:00:00', '2018-10-01 16:00:00',
#                '2018-10-02 09:00:00', '2018-10-02 10:00:00'],
#               dtype='datetime64[ns]', freq='BH')

# %%
pd.date_range(start='2018-10-01 08:00', periods=10, freq='30min')
# Out:
# DatetimeIndex(['2018-10-01 08:00:00', '2018-10-01 08:30:00',
#                '2018-10-01 09:00:00', '2018-10-01 09:30:00',
#                '2018-10-01 10:00:00', '2018-10-01 10:30:00',
#                '2018-10-01 11:00:00', '2018-10-01 11:30:00',
#                '2018-10-01 12:00:00', '2018-10-01 12:30:00'],
#               dtype='datetime64[ns]', freq='30T')

# %%
pd.date_range(start='2018-10-01 08:00', periods=10, freq='10S')
# Out:
# DatetimeIndex(['2018-10-01 08:00:00', '2018-10-01 08:00:10',
#                '2018-10-01 08:00:20', '2018-10-01 08:00:30',
#                '2018-10-01 08:00:40', '2018-10-01 08:00:50',
#                '2018-10-01 08:01:00', '2018-10-01 08:01:10',
#                '2018-10-01 08:01:20', '2018-10-01 08:01:30'],
#               dtype='datetime64[ns]', freq='10S')
